# %% [markdown]
# # DATA CLEANING

# %%
#importing Libraries

import pandas as pd
import numpy as np
import regex as re

from os import path
from PIL import Image
# !pip install wordcloud
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# Requirement already satisfied: wordcloud in c:\users\varti\anaconda3\lib\site-packages (1.8.2.2)
# Requirement already satisfied: matplotlib in c:\users\varti\anaconda3\lib\site-packages (from wordcloud) (3.5.1)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\varti\anaconda3\lib\site-packages (from wordcloud) (1.21.5)
# Requirement already satisfied: pillow in c:\users\varti\anaconda3\lib\site-packages (from wordcloud) (9.0.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\varti\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\varti\anaconda3\lib\site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\varti\anaconda3\lib\site-packages (from matplotlib->wordcloud) (3.0.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\varti\anaconda3\lib\site-packages (from matplotlib->wordcloud) (21.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\varti\anaconda3\lib\site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\varti\anaconda3\lib\site-packages (from matplotlib->wordcloud) (4.25.0)
# Requirement already satisfied: six>=1.5 in c:\users\varti\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)

# %%
#loading dataset as dataframe

pd_tweets=pd.read_csv('covid19_tweets.csv')

# %%
pd_tweets.head(50)
# Out:
#                                user_name  \
# 0                                 ᏉᎥ☻լꂅϮ
# 1                          Tom Basile 🇺🇸
# 2                        Time4fisticuffs
# 3                            ethel mertz
# 4                               DIPR-J&K
# 5                       🎹 Franz Schubert
# 6                           hr bartender
# 7                         Derbyshire LPC
# 8                      Prathamesh Bendre
# 9      Member of Christ 🇨🇳🇺🇸🇮🇳🇮🇩🇧🇷🇳🇬🇧🇩🇷🇺
# 10                Voice Of CBSE Students
# 11                           Creativegms
# 12                            SEXXYLYPPS
# 13    Africa Youth Advisory Board on DRR
# 14                        DailyaddaaNews
# 15                         Dimapur 24/7.
# 16                        ChennaiCityNow
# 17                  marc goovaerts🇪🇺🏳️‍🌈
# 18                            Dorian Aur
# 19                       Coronavirus Law
# 20                     The Voice of GenX
# 21                     APO Group English
# 22                          Micah Pollak
# 23                                 CAWST
# 24                        Florian Bieber
# 25                    Blood Donors India
# 26  Tetra Tech International Development
# 27            beatnikgeek the soothsayer
# 28                  Mugilan Chandrakumar
# 29               🏎🚒🚨☎️⚖️☎️📩📥📧 TAX Reform
# 30                                Ms Paz
# 31                             V2Cinemas
# 32                         Beautify Data
# 33                           Alan Taylor
# 34              The Bishop's Table Hotel
# 35            Higher Health South Africa
# 36                               harleyb
# 37                       WASH FOR HEALTH
# 38                               Mr Gazz
# 39                                  ASHP
# 40                     Aishling Sheridan
# 41              Matthew McGee ⴵ 🌍🇪🇺🇬🇧🎭🎞📚
# 42                        N I C TA S H ♍
# 43                             TOI Delhi
# 44                  🏳️‍🌈Heath Walker🏳️‍🌈
# 45                   Dr. K. Surender Raj
# 46                             Los Pepes
# 47                         Wanda Warwick
# 48                       Horace Hamilton
# 49                          HelloHealthy
#
#                                         user_location  \
# 0                                          astroworld
# 1                                        New York, NY
# 2                                    Pewee Valley, KY
# 3                                Stuck in the Middle
# 4                                   Jammu and Kashmir
# 5                                         Новоро́ссия
# 6                                     Gainesville, FL
# 7                                                 NaN
# 8                                                 NaN
# 9                          👇🏻location at link below👇🏻
# 10                                                NaN
# 11                                   Dhaka,Bangladesh
# 12  Hotel living - various cities!  Who needs a ho...
# 13                                             Africa
# 14                                          New Delhi
# 15                                    Nagaland, India
# 16                                                NaN
# 17                                           Brussels
# 18                                                NaN
# 19                                       Florida, USA
# 20                                                NaN
# 21                                      #AFRICA #MENA
# 22                                  Northwest Indiana
# 23                                     100+ countries
# 24                                               Graz
# 25                                      Mumbai, India
# 26                          Working in 175+ countries
# 27                                      Manhattan, NY
# 28                      no e-pass to cross borders...
# 29                                   I ♥️ I ♥️ I ♥️ I
# 30                                      United States
# 38  European citizen, educator. Proud Dad. Fan of ...  2010-08-25 13:01:56
# 39  ASHP — Representing #pharmacists who serve as ...  2009-09-15 19:52:43
# 40  Athletic therapist and trainer ✌️ Cavan ladies...  2011-12-21 18:19:44
# 41  I am a man, and nothing human is alien to me. ...  2011-12-07 11:16:36
# 42                                 I.G: @nictash_tash  2016-04-28 09:05:56
# 43  Your city. Your neighborhood. Your block. Cove...  2009-04-13 13:00:35
# 44  Single 🏳️‍🌈GAY🏳️‍🌈 Indy Lib #HowieHawkins2020 ...  2012-07-27 13:54:06
# 45  DMK Cuddalore Dist. Students Wing Joint Sec.\n...  2020-04-05 12:01:02
# 46                                                NaN  2016-04-23 07:39:51
# 47  Travel Tweets from a Worldwide Traveller - 110...  2016-09-01 13:00:41
# 48  The best laid schemes of Mice and Men \noften ...  2014-08-01 11:42:15
# 49                                                NaN  2012-11-23 05:38:37
#
#     user_followers  user_friends  user_favourites  user_verified  \
# 0              624           950            18775          False
# 1             2253          1677               24           True
# 2             9275          9525             7254          False
# 3              197           987             1488          False
# 4           101009           168              101          False
# 5             1180          1071             1287          False
# 6            79956         54810             3801          False
# 7              608           355               95          False
# 8               25            29               18          False
# 9            55201         34239            29802          False
# 10               8            10                7          False
# 11             241          1694             8443          False
# 12               0             8               32          False
# 13             830           254             3692          False
# 14             546            29               88          False
# 15             274            32              378          False
# 16            3987            53              749          False
# 17             283          1432             1546          False
# 18              46           108              453          False
# 19              14            24               74          False
# 20             292          1037               58          False
# 21           10661             6             2037           True
# 22             751           183             1308          False
# 23            3038          2713             7445          False
# 24           18145          1389            13578          False
# 25         1215920          2047            19359           True
# 26           20699           458             2680          False
# 27              86           259             9412          False
# 28            8205          1083            32076          False
# 29              28          1449             1196          False
# 30             127           974            30217          False
# 31           55589           548            10526          False
# 32              82            92             1152          False
# 33              54           422             1392          False
# 34             387           195               26          False
# 35            1934           247              722          False
# 36            6156          5463           193090          False
# 37            1657           823             2008          False
# 38            1416          1637            46021          False
# 39           32008          3763             7862           True
# 40            1136           484             2002          False
# 41            3113          3086           221545          False
# 42             481           308             1120          False
# 43           52186            41               74           True
# 44             594          1012            37279          False
# 45             152           885             1496          False
# 46             610          1446             3280          False
# 47             510           276              156          False
# 48             798           689              183          False
# 49             951           291              155          False
#
#                    date                                               text  \
# 0   2020-07-25 12:27:21  If I smelled the scent of hand sanitizers toda...
# 1   2020-07-25 12:27:17  Hey @Yankees @YankeesPR and @MLB - wouldn't it...
# 2   2020-07-25 12:27:14  @diane3443 @wdunlap @realDonaldTrump Trump nev...
# 3   2020-07-25 12:27:10  @brookbanktv The one gift #COVID19 has give me...
# 4   2020-07-25 12:27:08  25 July : Media Bulletin on Novel #CoronaVirus...
# 5   2020-07-25 12:27:06  #coronavirus #covid19 deaths continue to rise....
# 6   2020-07-25 12:27:03  How #COVID19 Will Change Work in General (and ...
# 7   2020-07-25 12:27:00  You now have to wear face coverings when out s...
# 8   2020-07-25 12:26:59  Praying for good health and recovery of @Chouh...
# 9   2020-07-25 12:26:54  POPE AS GOD - Prophet Sadhu Sundar Selvaraj. W...
# 10  2020-07-25 12:26:53  49K+ Covid19 cases still no response from \n@c...
# 11  2020-07-25 12:26:50  Order here: https://t.co/4NUrGX6EmA\n\n#logo #...
# 12  2020-07-25 12:26:47  👋🏻@PattyHajdu @NavdeepSBains — no one will be ...
\
# 0                                                 NaN
# 1                                                 NaN
# 2                                         ['COVID19']
# 3                                         ['COVID19']
# 4                   ['CoronaVirusUpdates', 'COVID19']
# 5                          ['coronavirus', 'covid19']
# 6                           ['COVID19', 'Recruiting']
# 7                                                 NaN
# 8                        ['covid19', 'covidPositive']
# 9                       ['HurricaneHanna', 'COVID19']
# 10                                                NaN
# 11  ['logo', 'graphicdesigner', 'logodesign', 'log...
# 12                                        ['COVID19']
# 13                                        ['COVID19']
# 14                                                NaN
# 15                  ['Covid19', 'keepsocialdistance']
# 16                ['COVID19', 'TamilNadu', 'chennai']
# 17                            ['COVID19', 'homework']
# 18                                          ['light']
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                ['WASH', 'COVID19']
# 24                                        ['COVID19']
# 25                      ['Kolar', 'Blood', 'COVID19']
# 26                           ['BosniaandHerzegovina']
# 27                                        ['COVID19']
# 28                ['TNCoronaUpdate', 'TN', 'COVID19']
# 29                                                NaN
# 30                  ['FEMA', 'PuertoRico', 'COVID19']
# 31                              ['Covid19', 'Vishal']
# 32                              ['covid19', 'Africa']
# 33                                        ['COVID19']
# 34                                                NaN
# 35                                                NaN
# 36                                        ['COVID19']
# 37                             ['COVID19', 'climate']
# 38                 ['BorisJohnson', '5COBRA', 'Five']
# 39                                        ['COVID19']
# 40                        ['PlayYourPart', 'COVID19']
# 41                                        ['Covid19']
# 42                                        ['COVID19']
# 43                               ['Delhi', 'COVID19']
# 44                                                NaN
# 45                           ['TamilNadu', 'COVID19']
# 46                   ['RutoSwindlingGEMA', 'COVID19']
# 47                                                NaN
# 48                                                NaN
# 49                           ['TamilNadu', 'COVID19']
#
#                      source  is_retweet
# 0        Twitter for iPhone       False
# 1       Twitter for Android       False
# 2       Twitter for Android       False
# 3        Twitter for iPhone       False
# 4       Twitter for Android       False
# 5           Twitter Web App       False
# 6                    Buffer       False
# 7                 TweetDeck       False
# 8       Twitter for Android       False
# 9        Twitter for iPhone       False
# 10          Twitter Web App       False
# 11          Twitter Web App       False
# 12          Twitter Web App       False
# 13          Twitter Web App       False
# 14          Twitter Web App       False
# 15      Twitter for Android       False
# 16       Twitter for iPhone       False
# 17      Twitter for Android       False
# 18          Twitter Web App       False
# 19         Twitter for iPad       False
# 20       Twitter for iPhone       False
# 21          Africa Newsroom       False
# 22          Twitter Web App       False
# 23       Twitter for iPhone       False
# 24      Twitter for Android       False
# 25       Blood Donors India       False
# 26          Twitter Web App       False
# 27      Twitter for Android       False
# 28      Twitter for Android       False
# 29         Twitter for iPad       False
# 30       Twitter for iPhone       False
# 31      Twitter for Android       False
# 32          Twitter Web App       False
# 33         Twitter for iPad       False
# 34          Twitter Web App       False
# 35       Twitter for iPhone       False
# 36      Twitter for Android       False
# 37       Twitter for iPhone       False
# 38      Twitter for Android       False
# 39          Twitter Web App       False
# 40       Twitter for iPhone       False
# 41      Twitter for Android       False
# 42      Twitter for Android       False
# 43                TweetDeck       False
# 44      Twitter for Android       False
# 45       Twitter for iPhone       False
# 46      Twitter for Android       False
# 47  TweetCaster for Android       False
# 48  TweetCaster for Android       False
# 49      Twitter for Android       False

# %%
#Lower Case Conversion of strings
pd_tweets['user_name']=pd_tweets['user_name'].str.lower()
pd_tweets['user_location']=pd_tweets['user_location'].str.lower()
pd_tweets['user_description']=pd_tweets['user_description'].str.lower()
pd_tweets['text']=pd_tweets['text'].str.lower()
pd_tweets['hashtags']=pd_tweets['hashtags'].str.lower()

#Removing usernames and hashtags and links from tweets
pd_tweets['text']=pd_tweets['text'].str.replace('(@\w+.*?)',"",regex=True)
pd_tweets['text'] = pd_tweets['text'].str.replace("#[A-Za-z0-9_]+","", regex=True)
pd_tweets['text']=pd_tweets['text'].str.replace(r'http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\(\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+',"",regex=True)


#Remove special charecters from tweets
pd_tweets['text']=pd_tweets['text'].str.replace('[@,#,%,:,?,-,$,_,.,!,/,),(,=,;,*]',"",regex=True) 
pd_tweets['text']=pd_tweets['text'].str.replace(r'-',"",regex=True) 
pd_tweets['text']=pd_tweets['text'].str.replace('\[',"",regex=True) 
pd_tweets['text']=pd_tweets['text'].str.replace(']',"",regex=True)

# %%
#removing newline character from tweets and punctuation marks
pd_tweets['text']=pd_tweets['text'].str.replace('\n',"",regex=True)
pd_tweets['text'] = pd_tweets['text'].str.replace('[()!?]', ' ', regex=True)
pd_tweets['text'] = pd_tweets['text'].str.replace('\[.*?\]',' ', regex=True)

# %%
#filtering out non-alpha numeric charecters (including emojis etc)

pd_tweets['text'] = pd_tweets['text'].str.replace("[^a-z0-9]"," ", regex=True)

# %%
pd.set_option("display.max_colwidth", None)
pd_tweets[['text']].head(50)
# Out:
#                                                                                                                     text
# 0   if i smelled the scent of hand sanitizers today on someone in the past i would think they were so intoxicated that
# 1                         hey   and   wouldn t it have made more sense to have the players pay their respects to the a
# 2                                                trump never once claimed  was a hoax we all claim that this effort to
# 3                        the one gift  has give me is an appreciation for the simple things that were always around me
# 4                                                                               25 july  media bulletin on novel
# 5                          deaths continue to rise it s almost  as bad as it ever was  politicians and businesses want
# 6                                                   how  will change work in general and recruiting specifically via
# 7        you now have to wear face coverings when out shopping  this includes a visit to your local community pharmacy
# 8                                                                              praying for good health and recovery of
# 9                                                          pope as god  prophet sadhu sundar selvaraj watch here at
# 10                                       49k  covid19 cases still no response from   please cancel the compartment exa
# 11                                                                                                  order here
# 12                                          no one will be safe from  until everyone is safe will you commit to ensure
# 13             let s all protect ourselves from it s real and the numbers are climbing up fast in the continentlet s n
# 14  rajasthan government today started a plasma bank at sawai man singh hospital in jaipur for treatment of covid19 pa
# 15                                                nagaland police on covid19 awareness at city tower junction dimapur
# 16                                      july 25  update  6988discharge 7758people tested  61729actice cases  52273  1329
# 17                                                                       second wave of  in flandersback to more  again
# 18                                          it is during our darkest moments that we must focus to see the  aristotle
# 19  covid update the infection rate in florida is following the natural curve that experts predicted if the initial cu
# 20                                    good patriotscall to volunteer to be an election judge polls cannot open without
# 21                                           coronavirus  south africa covid19 update for south africa 24 july 2020
# 22              your image doesn t list a source but i d be careful with overall  risk of dying  statistics related to
# 23                the first comprehensive review of   amp analysis key ways in which wash can help reduce transmission
# 24                                                                                              holy water in times of
# 25                            need  type   bpositiveat  jalappa hospitalblood component  need plasma from b ve  recove
# 26                         our munitions response team in  modified ops and adopted masks disinfectants and sanitizers
# 27         i can imagine the same people profiting off the human suffering of  will be studying these maps to make 207
# 28                                    crosses 2 lakh mark and 150055 ppp has recovered so far positive today 6988total
# 29                       tax reformtaxfree minimumfor a company of five hundred thousand euros per yeartaxfree minimum
# 30                                                        acknowledges  lacks rebuilt homes and a hospital to survive
# 31                                        actor  and his father mrgkreddy tested positive for  1520 days backwhile   s
# 32                   an update on the total  cases recoveries and deaths reported in countries in   see the total numb
# 33                                            regarding the community outbreak of  on haida gwaii 13 cases one recover
# 34   a safe place to visit here is what our guests said  the hotel were meticulous in applying hand sanitation and als
# 35                                          our ceo  live with  wsu talking about  the effects of covid19 on students
# 36                                            i m feeling a little anxious because  seems to have detracted everyone s
# 37                                                                           actionables for a healthy recovery from
# 38                                                   well  might have understood more if he hadn t missed  meeting  in
# 39              we released two new  podcast episodes this weektechnology platforms used to conduct telehealth visitsc
# 40                           in the fight against   each one of us can make a difference in containing the spread lets
# 41          britain didn t understand  for months while plenty of other countries did understand it and took effective
# 42                                                                               volume for those at the back please
# 43                    reports 1142  positive cases and 29 deaths on saturday death toll rises to 3806 reports ani quot
# 44                     venezuela s economybudget are tied to oil like louisiana s funny how the rightwing  example  of
# 45                                           25th july   tn  6988 highest spike   total cases   206737   chennai  1329
# 46                                                      why has ruto not eulogisied mkapa asking for moses kuria raila
# 47   coronavirus testing fiasco st mirren have pledged to undertake an  urgent review  of their covid19 testing proced
# 48   coronavirus testing fiasco st mirren have pledged to undertake an  urgent review  of their covid19 testing proced
# 49                                       25th july   tn  6988 highest spike   total cases   206737   chennai  1329   t

# %%
#Description of Dataset
pd_shape=pd_tweets.shape
pd_summ=pd_tweets.describe()
pd_dtypes=pd_tweets.dtypes

print("Shape of Data is: ", pd_shape,"\n\nDescriptive Stats of Dataset:\n\n",pd_summ,"\n\nDatatypes of Dataframe:\n\n ",pd_dtypes)
# Out:
# Shape of Data is:  (179108, 13)
#
# Descriptive Stats of Dataset:
#
#         user_followers   user_friends  user_favourites
# count    1.791080e+05  179108.000000     1.791080e+05
# mean     1.090555e+05    2121.701566     1.444411e+04
# std      8.414670e+05    9162.553072     4.452270e+04
# min      0.000000e+00       0.000000     0.000000e+00
# 25%      1.720000e+02     148.000000     2.060000e+02
# 50%      9.920000e+02     542.000000     1.791000e+03
# 75%      5.284000e+03    1725.250000     9.388000e+03
# max      4.944256e+07  497363.000000     2.047197e+06
#
# Datatypes of Dataframe:
#
#   user_name           object
# user_location       object
# user_description    object
# user_created        object
# user_followers       int64
# user_friends         int64
# user_favourites      int64
# user_verified         bool
# date                object
# text                object
# hashtags            object
# source              object
# is_retweet            bool
# dtype: object

# %% [markdown]
# # Exploratory Data Analysis

# %%
#Number of missing tweets after cleaning

print("Number of Missing Tweets Are: ",pd_tweets['text'].isna().sum())
# Out:
# Number of Missing Tweets Are:  0

# %%
pd_tweets.to_csv("updated_tweets.csv")

# %%
# this is to show the top 20 user locations of the tweets 

location = pd_tweets.value_counts('user_location')
top20Locations = location.head(20)

top20Locations.to_frame()
plt.style.use('seaborn')
plt.figure( figsize=(20,10) )
plt.title("Number of tweets from different locations",fontsize= 16)
chart = top20Locations.plot(kind='bar', stacked=True, rot='45', colormap='viridis',fontsize= 12)
chart.set_xlabel("Locations")
chart.set_ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %%
# this is to show the top 15 user  of tweets

user = pd_tweets.value_counts('user_name')
top20Users = user.head(15)

plt.figure( figsize=(20,10) )
plt.title("Number of tweets from top 15 users",fontsize= 16)
chart = top20Users.plot(kind='bar', stacked=True, colormap='rainbow',fontsize= 12)
chart.set_xlabel("Users",fontsize= 14)
chart.set_ylabel("Frequency",fontsize= 14)
# Out:
# Text(0, 0.5, 'Frequency')

# %%
# this is to generate the most common words in the tweets
text = " ".join(tweet for tweet in pd_tweets["text"])

# Create and generate a word cloud image:
wordcloud = WordCloud(max_font_size=50, background_color='white',max_words=100,width=500, height=300).generate(text)

# Display the generated image:
plt.figure( figsize=(20,10) )
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
pd_tweets['formatted_date'] = pd_tweets['date'].str.split(" ")
pd_tweets[['formatted_date','formatted_time']] = pd_tweets['date'].str.split(" ",2,expand=True)

pd_tweets["formatted_date"] = pd.to_datetime(pd_tweets["formatted_date"])
pd_tweets = pd_tweets.sort_values(by="date")
pd_tweets.head(1)
# Out:
#                    user_name  user_location  \
# 17175  jessica luther rummel  denton, texas
#
#                                                    user_description  \
# 17175  mother. partner. scholar. activist. alchemist. \njai kali ma
#
#               user_created  user_followers  user_friends  user_favourites  \
# 17175  2020-07-05 03:28:16             234            28              220
#
#        user_verified                 date  \
# 17175          False  2020-07-24 23:47:08
#
#                                                                                                                   text  \
# 17175  protestors needed 6pm10pm daily now 1450 e mckinney denton county jail covid19 outbreak released trustee repo
#
#       hashtags           source  is_retweet formatted_date formatted_time
# 17175      NaN  Twitter Web App       False     2020-07-24       23:47:08

# %%
pd_tweets.tail(1)
# Out:
#          user_name user_location  \
# 166656  🍺¯\_(ツ)_/¯    boston, ma
#
#                                                                                        user_description  \
# 166656  father, husband, musician, dog-lover. all opinions are my own and should probably be yours too.
#
#                user_created  user_followers  user_friends  user_favourites  \
# 166656  2009-04-13 13:14:46              24           197             1409
#
#         user_verified                 date  \
# 166656          False  2020-08-30 09:07:39
#
#                                                                                                          text  \
# 166656  it s a shame magots can t celebrate  s revisionist math in the cdc s  updated  death toll on accoun
#
#        hashtags              source  is_retweet formatted_date formatted_time
# 166656      NaN  Twitter for iPhone       False     2020-08-30       09:07:39

# %%
# this is to generate the most common devices used to tweet

source = pd_tweets.value_counts('source')
top20sources = source.head(20)
my_cmap = plt.get_cmap("Set1")

plt.style.use('seaborn')
sns.set_style(style='white')
plt.figure( figsize=(20,10) )
chart = top20sources.plot(kind='bar', stacked=True, color=my_cmap.colors, rot='90',fontsize= 15)
chart.set_xlabel("SOURCE",fontsize= 20)
chart.set_ylabel("FREQUENCY OF TWEETS",fontsize= 20)
# Out:
# Text(0, 0.5, 'FREQUENCY OF TWEETS')
